# %%
import pandas as pd
import dask as dd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import statsmodels.formula.api as smf

from sklearn.linear_model import LogisticRegression

import statsmodels.api as sm
from statsmodels.genmod.generalized_linear_model import GLM
from statsmodels.genmod import families
from statsmodels.stats.outliers_influence import variance_inflation_factor

from scipy import stats
# Out:
# /usr/local/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
df = pd.read_csv('./data/JV_data_dist.csv', index_col='da', parse_dates=True )

# %%
df
# Out:
#                   id                                           activity  \
# da
# 2002-01-01   88623.0                                 Financial Services
# 2002-01-03   88649.0                             Manufacturing Services
# 2002-01-04   88660.0  Property Development Services\nConstruction Se...
# 2002-01-08   88691.0                             Manufacturing Services
# 2002-01-08   88699.0                             Manufacturing Services
# ...              ...                                                ...
# 2012-12-02  135098.0                                Automotive Services
# 2012-12-05  135144.0  Manufacturing Services\nRetail & Wholesale Ser...
# 2012-12-11  135218.0                             Manufacturing Services
# 2012-12-18  135299.0                        Retail & Wholesale Services
# 2012-12-18  135302.0                   Transportation (Public) Services
#
#                 activityc jvinc                                 jvindustry  \
# da
# 2002-01-01            FIN    DC                        Credit Institutions
# 2002-01-03            MNF    AN                                  Machinery
# 2002-01-04  PDS\nCSN\nREI    DD  Real Estate; Mortgage Bankers and Brokers
# 2002-01-08            MNF    AS                   Transportation Equipment
# 2002-01-08            MNF    AS                   Transportation Equipment
# ...                   ...   ...                                        ...
# 2012-12-02            AUT    AS                   Transportation Equipment
# 2012-12-05       MNF\nRWS    AS                   Transportation Equipment
# 2012-12-11            MNF    AS                   Transportation Equipment
# 2012-12-18            RWS    CA              Wholesale Trade-Durable Goods
# 2012-12-18            TPS    BL                          Business Services
#
#                     jvstatus  \
# da
# 2002-01-01  Completed/Signed
# 2002-01-03  Completed/Signed
# 2002-01-04  Letter of Intent
# 2002-01-08  Completed/Signed
# 2002-01-08           Pending
# ...                      ...
# 2012-12-02  Completed/Signed
# 2012-12-05           Pending
# 2012-12-11           Pending
# 2012-12-18           Pending
# 2012-12-18  Completed/Signed
#
#                                                             p  \
# da
# 2002-01-01                       Toyota Motor Corp\nMetrobank
# 2002-01-03       SAIC\nYuejin Automobile Group Co\nTeksid SpA
# 2002-01-04  Raba Automotive Holding Plc\nEngel General Dev...
# 2002-01-08  Hyundai Corp\nMitsubishi Corp\nDaimlerChrysler AG
# 2002-01-08                   Proton\nGold Star Heavy Ind Mnfr
# ...                                                       ...
# 2012-12-02                GAZ\nMersa Otomotiv Motorlu Araclar
# 2012-12-05  SAIC Motor Corp Ltd\nCharoen Pokphand Group Co...
# 2012-12-11                         BYD Co Ltd\nBulmineral Ltd
# 2012-12-18                                   Daimler AG\nBAIC
# 2012-12-18  Volvo AB\nVolvo-Worldwide Passenger Bus\nChalm...
#
#                                                           pbl  \
# da
# 2002-01-01  Toyota Motor Corp,\nheadquartered in Aichi, Ja...
# 2002-01-03  Shanghai Automotive Industry\nCorp (Group), lo...
# 2002-01-04  Raba Automotive Holding Plc,\nlocated in Gyor,...
# 2002-01-08  Hyundai Corp, located in\nSeoul, South Korea, ...
# 2002-01-08  Manufacture and retail motor\nvehicles; wholes...
# ...                                                       ...
# 2012-12-02  GAZ OAO, located in Nizhnii\nNovgorod, Russian...
# 2012-12-05  SAIC Motor Corp Ltd, located\nin Shanghai, Chi...
# 2012-12-11  BYD Co Ltd located in\nShenzhen, China, manufa...
# 2012-12-18  Daimler AG, located in\nStuttgart, Germany,\nm...
# 2012-12-18  Volvo AB, located in\nGothenburg, Sweden,\nman...
#
#                                                         pbuss  sicp  ...  \
# da                                                                   ...
# 2002-01-01                Mnfr passenger motor vehicles\nBank  6141  ...
# 2002-01-03  Mnfr,whl motor vehicles,parts\nMnfr motor vehi...  3561  ...
# 2002-01-04         Mnfr,whl commercial vehicles\nRE dvlp firm  6552  ...
# 2002-01-08  Whl automobiles,metal prods\nMnfr,whl auto,che...  3711  ...
# 2002-01-08           Mnfr,ret motor vehicles\nMnfr auto parts  3714  ...
# ...                                                       ...   ...  ...
# 2012-12-02  Manufacture,whl motor vehicles\nMnfr,wholesale...  3711  ...
# 2012-12-05  Mnfr,whl motor vehicles,parts\nOwn,operate gen...  3711  ...
# 2012-12-11     Mnfr,whl automobiles,parts\nInvestment company  3711  ...
# 2012-12-18  Manufacture, wholesale passenger cars\nMnfr,wh...  5012  ...
# 2012-12-18  Mnfr,whl motor vehicles,parts\nManufacture pas...  7389  ...
#
#            ddist_bin     p1emp     p2emp     p3emp  p4emp p5emp p6emp p7emp  \
# da
# 2002-01-01         0   69478.0   12114.0       NaN    NaN   NaN   NaN   NaN
# 2002-01-03         0       NaN       NaN       NaN    NaN   NaN   NaN   NaN
# 2002-01-04         0       NaN       NaN       NaN    NaN   NaN   NaN   NaN
# 2002-01-08         0     267.0   60520.0  382724.0    NaN   NaN   NaN   NaN
# 2002-01-08         0       NaN       NaN       NaN    NaN   NaN   NaN   NaN
# ...              ...       ...       ...       ...    ...   ...   ...   ...
# 2012-12-02         1       NaN       NaN       NaN    NaN   NaN   NaN   NaN
# 2012-12-05         1   65000.0  280000.0       NaN    NaN   NaN   NaN   NaN
# 2012-12-11         1  160000.0       NaN       NaN    NaN   NaN   NaN   NaN
# 2012-12-18         1  280829.0       NaN       NaN    NaN   NaN   NaN   NaN
# 2012-12-18         1  100000.0       NaN       NaN    NaN   NaN   NaN   NaN
#
#            p8emp p9emp
# da
# 2002-01-01   NaN   NaN
# 2002-01-03   NaN   NaN
# 2002-01-04   NaN   NaN
# 2002-01-08   NaN   NaN
# 2002-01-08   NaN   NaN
# ...          ...   ...
# 2012-12-02   NaN   NaN
# 2012-12-05   NaN   NaN
# 2012-12-11   NaN   NaN
# 2012-12-18   NaN   NaN
# 2012-12-18   NaN   NaN
#
# [989 rows x 52 columns]
